# %%
import cv2
from matplotlib import pyplot as plt

# %%
cap = cv2.VideoCapture(0)
ret, frame = cap.read()
frame
# Out:
# array([[[118, 136, 171],
#         [118, 136, 171],
#         [119, 137, 173],
#         ...,
#         [197, 218, 217],
#         [197, 218, 217],
#         [198, 219, 218]],
#
#        [[116, 136, 171],
#         [117, 137, 173],
#         [119, 137, 173],
#         ...,
#         [198, 219, 218],
#         [197, 218, 217],
#         [197, 218, 217]],
#
#        [[119, 137, 173],
#         [119, 137, 173],
#         [122, 139, 175],
#         ...,
#         [197, 218, 217],
#         [198, 219, 218],
#         [197, 218, 217]],
#
#        ...,
#
#        [[ 25,  33,  31],
#         [ 27,  34,  33],
#         [ 25,  33,  31],
#         ...,
#         [  4,  13,   7],
#         [  6,  14,   8],
#         [  3,  12,   6]],
#
#        [[ 27,  36,  35],
#         [ 27,  36,  35],
#         [ 29,  36,  35],
#         ...,
#         [  6,  14,   8],
#         [  7,  16,  10],
#         [  4,  13,   7]],
#
#        [[ 28,  37,  38],
#         [ 28,  37,  38],
#         [ 29,  38,  39],
# ...

# %%
plt.imshow(frame)

# %%
cap.release()
